# %% [markdown]
# ## Deep learning experiments
#
# This notebook accumulates deep learning experiments for all benchmark datasets that can be handled with standard reservoir memory machines, in particular the latch, copy, repeat copy, and signal copy task. We test here a standard gated recurrent unit as well as a gated recurrent unit with a state mechanism like the reservoir memory machine.
#
# *Note:* Executing this notebook may take very long (> 1 day), especially for the signal copy task.

# %%
# in this first cell we set some experimental meta-parameters that are used across all
# datasets

# the number of training time series
N = 90
# the number of test time series
N_test = 10
# the number of repeats for the experiments
R = 3
# the names of the tasks to be performed
tasks = ['latch', 'copy', 'repeat_copy', 'signal_copy']
# the number of neurons for each task
ms = [64, 256, 256, 64]
# the number of input dimensions for each task
ns = [1, 9, 9, 2]
# the memory size for each task
Ks = [2, 21, 11, 2]
# the output size for each task
Ls = [1, 8, 8, 1]

# hyper-parameters for training

# the maximum number of epochs
num_epochs = 1000
# loss threshold for early stopping
loss_threshold = 1E-3
# minibatch size
minibatch_size = 32
# the learning rate
lr = 1E-3
# the weight decay factor
weight_decay = 1E-8

# variables for error reporting
# update factor for moving average over the loss
avg_factor = 0.1
# number of steps until error is printed
print_step = 50

# model names
models = ['GRU', 'GRU-MM']

# %% [markdown]
# ## Experiment
#
# After all the hyperparameter setup above we can now iterate over all tasks and
# perform the experiments. Be advised that it may take ~a day to complete all cells.

# %%
import numpy as np
import torch
import rmm2.deep_memory_machine as dmm
import json
import random
import time
from dataset_generators import generate_data

# iterate over all tasks
for task_idx in range(len(tasks)):
    task = tasks[task_idx]
    print('------ Task %d of %d: %s -----' % (task_idx+1, len(tasks), task))
    # load task hyperparameters
    m = ms[task_idx]
    n = ns[task_idx]
    K = Ks[task_idx]
    L = Ls[task_idx]
    # initialize error and runtime arrays
    errors   = np.zeros((len(models), R))
    runtimes = np.zeros((len(models), R))
    # iterate over all experimental repeats
    for r in range(R):
        print('--- repeat %d of %d ---' % (r+1, R))
        # sample training and test data
        Xs, Qs, Ys = generate_data(N, task)
        Xs_test, Qs_test, Ys_test = generate_data(N_test, task)
        # now iterate over all models
        for model_idx in range(len(models)):
            model = models[model_idx]
            print('-- model: %s --' % model)
            # set up the model
            start_time = time.time()
            if model == 'GRU':
                net = dmm.GRUInterface(m, n, L)
            elif model == 'GRU-MM':
                net = dmm.DeepMemoryMachine(m, n, K, L)
            # set up an optimizer
            optim = torch.optim.Adam(net.parameters(), lr = lr, weight_decay = weight_decay)
            # set up aux variables
            loss_avg = None
            j = N
            # start training
            for epoch in range(num_epochs):
                optim.zero_grad()
                # generate a new permutation of the data
                if j + minibatch_size >= N:
                    pi = np.random.permutation(N)
                    j = 0
                # generate minibatch of data
                minibatch_loss = torch.zeros(1)
                for i in range(minibatch_size):
                    X, Q, Y = Xs[pi[j]], Qs[pi[j]], Ys[pi[j]]
                    j += 1
                    # compute the loss
                    if model == 'GRU':
                        Ypred = net(X)
                        loss  = torch.nn.functional.mse_loss(Ypred, torch.tensor(Y, dtype=torch.float))
                    else:
                        loss  = net.compute_teacher_forcing_loss(X, Q, Y)
                    # add to minibatch
                    minibatch_loss = minibatch_loss + loss
                # compute gradient
                minibatch_loss.backward()
                # perform optimization step
                optim.step()
                # record loss
                if loss_avg is None:
                    loss_avg = minibatch_loss.item() / minibatch_size
                else:
                    loss_avg = avg_factor * minibatch_loss.item() / minibatch_size + (1. - avg_factor) * loss_avg
                if (epoch + 1) % print_step == 0:
                    print('moving average loss in epoch %d: %g' % (epoch+1, loss_avg))
                if loss_avg < loss_threshold:
                    print('ended training already after %d epochs because moving average loss %g was below loss threshold.' % (epoch + 1, loss_avg))
                    break
            # measure the RMSE on the test data
            mse = 0.
            for i in range(N_test):
                Ypred = net(Xs_test[i])
                mse   += np.mean((Ypred.detach().numpy() - Ys_test[i]) ** 2)
            rmse = np.sqrt(mse / N_test)
            runtimes[model_idx, r] = time.time() - start_time
            errors[model_idx, r] = rmse
    # print results
    for model_idx in range(len(models)):
        print('%s: %g +- %g (took %g seconds)' % (models[model_idx], np.mean(errors[model_idx, :]), np.std(errors[model_idx, :]), np.mean(runtimes[model_idx, :])))
    # write results to file
    np.savetxt('%s_deep_errors.csv' % task, errors.T, delimiter='\t', header='\t'.join(models), comments='')
    np.savetxt('%s_deep_runtimes.csv' % task, runtimes.T, delimiter='\t', header='\t'.join(models), comments='')
# Out:
# ------ Task 1 of 5: latch -----
# --- repeat 1 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.241303
# moving average loss in epoch 100: 0.235658
# moving average loss in epoch 150: 0.230335
# moving average loss in epoch 200: 0.226912
# moving average loss in epoch 250: 0.217274
# moving average loss in epoch 300: 0.180054
# moving average loss in epoch 350: 0.159764
# moving average loss in epoch 400: 0.152201
# moving average loss in epoch 450: 0.147697
# moving average loss in epoch 500: 0.13902
# moving average loss in epoch 550: 0.139724
# moving average loss in epoch 600: 0.137675
# moving average loss in epoch 650: 0.133143
# moving average loss in epoch 700: 0.130034
# moving average loss in epoch 750: 0.127991
# moving average loss in epoch 800: 0.111145
# moving average loss in epoch 850: 0.0237343
# moving average loss in epoch 900: 0.00442437
# moving average loss in epoch 950: 0.00250686
# moving average loss in epoch 1000: 0.00184261
# -- model: GRU-MM --
# moving average loss in epoch 50: 0.961258
# moving average loss in epoch 100: 0.446759
# moving average loss in epoch 150: 0.207551
# moving average loss in epoch 200: 0.179583
# moving average loss in epoch 250: 0.157462
# moving average loss in epoch 300: 0.149499
# moving average loss in epoch 350: 0.133987
# moving average loss in epoch 400: 0.118021
# moving average loss in epoch 450: 0.106063
# moving average loss in epoch 500: 0.0926608
# moving average loss in epoch 550: 0.0878707
# moving average loss in epoch 600: 0.0776171
# moving average loss in epoch 650: 0.0735253
# moving average loss in epoch 700: 0.0682891
# moving average loss in epoch 750: 0.0612627
# moving average loss in epoch 800: 0.0520158
# moving average loss in epoch 850: 0.0434501
# moving average loss in epoch 900: 0.0307995
# moving average loss in epoch 950: 0.0213058
# moving average loss in epoch 1000: 0.014767
# --- repeat 2 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.251172
# moving average loss in epoch 100: 0.233531
# moving average loss in epoch 150: 0.230204
# moving average loss in epoch 200: 0.227762
# moving average loss in epoch 250: 0.225717
# moving average loss in epoch 300: 0.221908
# moving average loss in epoch 350: 0.215246
# moving average loss in epoch 400: 0.170102
# moving average loss in epoch 450: 0.154041
# moving average loss in epoch 500: 0.141422
# moving average loss in epoch 550: 0.139339
# moving average loss in epoch 600: 0.12477
# moving average loss in epoch 650: 0.103867
# moving average loss in epoch 700: 0.0814394
# moving average loss in epoch 750: 0.024813
# moving average loss in epoch 800: 0.00544207
# moving average loss in epoch 850: 0.00278346
# moving average loss in epoch 900: 0.00170456
# moving average loss in epoch 950: 0.00123814
# ended training already after 991 epochs because moving average loss 0.000959225 was below loss threshold.
# -- model: GRU-MM --
# moving average loss in epoch 50: 0.987485
# moving average loss in epoch 100: 0.462609
# moving average loss in epoch 150: 0.196573
# moving average loss in epoch 200: 0.174485
# moving average loss in epoch 250: 0.16644
# moving average loss in epoch 300: 0.152679
# moving average loss in epoch 350: 0.141728
# moving average loss in epoch 400: 0.125542
# moving average loss in epoch 450: 0.106136
# moving average loss in epoch 500: 0.0880484
# moving average loss in epoch 550: 0.0733616
# moving average loss in epoch 600: 0.0578393
# moving average loss in epoch 650: 0.0460521
# moving average loss in epoch 700: 0.0362156
# moving average loss in epoch 750: 0.0261837
# moving average loss in epoch 800: 0.0196211
# moving average loss in epoch 850: 0.0147338
# moving average loss in epoch 900: 0.0112139
# moving average loss in epoch 950: 0.00866556
# moving average loss in epoch 1000: 0.00699082
# --- repeat 3 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.246152
# moving average loss in epoch 100: 0.236193
# moving average loss in epoch 150: 0.233734
# moving average loss in epoch 200: 0.229834
# moving average loss in epoch 250: 0.225231
# moving average loss in epoch 300: 0.211914
# moving average loss in epoch 350: 0.167152
# moving average loss in epoch 400: 0.145685
# moving average loss in epoch 450: 0.142736
# moving average loss in epoch 500: 0.136903
# moving average loss in epoch 550: 0.12386
# moving average loss in epoch 600: 0.126633
# moving average loss in epoch 650: 0.117597
# moving average loss in epoch 700: 0.110533
# moving average loss in epoch 750: 0.101261
# moving average loss in epoch 800: 0.093026
# moving average loss in epoch 850: 0.0485609
# moving average loss in epoch 900: 0.00880352
# moving average loss in epoch 950: 0.00600843
# moving average loss in epoch 1000: 0.00588838
# -- model: GRU-MM --
# moving average loss in epoch 50: 0.978632
# moving average loss in epoch 100: 0.423614
# moving average loss in epoch 150: 0.199291
# moving average loss in epoch 200: 0.184479
# moving average loss in epoch 250: 0.162733
# moving average loss in epoch 300: 0.15084
# moving average loss in epoch 350: 0.138042
# moving average loss in epoch 400: 0.116239
# moving average loss in epoch 450: 0.10229
# moving average loss in epoch 500: 0.0850375
# moving average loss in epoch 550: 0.0754135
# moving average loss in epoch 600: 0.0627304
# moving average loss in epoch 650: 0.0507211
# moving average loss in epoch 700: 0.038272
# moving average loss in epoch 750: 0.0291283
# moving average loss in epoch 800: 0.0224515
# moving average loss in epoch 850: 0.0168093
# moving average loss in epoch 900: 0.0123843
# moving average loss in epoch 950: 0.0101543
# moving average loss in epoch 1000: 0.00807919
# GRU: 0.0508074 +- 0.0353385 (took 510.268 seconds)
# GRU-MM: 0.00016615 +- 0.000117855 (took 1180.03 seconds)
# ------ Task 2 of 5: copy -----
# --- repeat 1 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.205252
# moving average loss in epoch 100: 0.133997
# moving average loss in epoch 150: 0.111216
# moving average loss in epoch 200: 0.108286
# moving average loss in epoch 250: 0.104707
# moving average loss in epoch 300: 0.0993484
# moving average loss in epoch 350: 0.0953929
# moving average loss in epoch 400: 0.091281
# moving average loss in epoch 450: 0.0880422
# moving average loss in epoch 500: 0.084183
# moving average loss in epoch 550: 0.0799971
# moving average loss in epoch 600: 0.0736649
# moving average loss in epoch 650: 0.0707994
# moving average loss in epoch 700: 0.0650552
# moving average loss in epoch 750: 0.0579412
# moving average loss in epoch 800: 0.0517107
# moving average loss in epoch 850: 0.0445496
# moving average loss in epoch 900: 0.0390273
# moving average loss in epoch 950: 0.0320691
# moving average loss in epoch 1000: 0.0254252
# -- model: GRU-MM --
# moving average loss in epoch 50: 1.81505
# moving average loss in epoch 100: 0.675778
# moving average loss in epoch 150: 0.299975
# moving average loss in epoch 200: 0.131261
# moving average loss in epoch 250: 0.0550337
# moving average loss in epoch 300: 0.0279237
# moving average loss in epoch 350: 0.0180501
# moving average loss in epoch 400: 0.0129054
# moving average loss in epoch 450: 0.00973402
# moving average loss in epoch 500: 0.00767835
# moving average loss in epoch 550: 0.00621344
# moving average loss in epoch 600: 0.0051499
# moving average loss in epoch 650: 0.004402
# moving average loss in epoch 700: 0.00376073
# moving average loss in epoch 750: 0.00327326
# moving average loss in epoch 800: 0.00288696
# moving average loss in epoch 850: 0.00258698
# moving average loss in epoch 900: 0.00229631
# moving average loss in epoch 950: 0.00205313
# moving average loss in epoch 1000: 0.00187362
# --- repeat 2 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.201959
# moving average loss in epoch 100: 0.130067
# moving average loss in epoch 150: 0.109977
# moving average loss in epoch 200: 0.107136
# moving average loss in epoch 250: 0.101191
# moving average loss in epoch 300: 0.0982021
# moving average loss in epoch 350: 0.0944066
# moving average loss in epoch 400: 0.0913526
# moving average loss in epoch 450: 0.0871933
# moving average loss in epoch 500: 0.0836655
# moving average loss in epoch 550: 0.0783641
# moving average loss in epoch 600: 0.0740974
# moving average loss in epoch 650: 0.066789
# moving average loss in epoch 700: 0.0613721
# moving average loss in epoch 750: 0.0559602
# moving average loss in epoch 800: 0.0498161
# moving average loss in epoch 850: 0.044138
# moving average loss in epoch 900: 0.0389793
# moving average loss in epoch 950: 0.032572
# moving average loss in epoch 1000: 0.0291979
# -- model: GRU-MM --
# moving average loss in epoch 50: 1.81226
# moving average loss in epoch 100: 0.660042
# moving average loss in epoch 150: 0.287556
# moving average loss in epoch 200: 0.126725
# moving average loss in epoch 250: 0.0554335
# moving average loss in epoch 300: 0.0285062
# moving average loss in epoch 350: 0.0181614
# moving average loss in epoch 400: 0.0128996
# moving average loss in epoch 450: 0.00973865
# moving average loss in epoch 500: 0.00763889
# moving average loss in epoch 550: 0.00609728
# moving average loss in epoch 600: 0.00511588
# moving average loss in epoch 650: 0.00428265
# moving average loss in epoch 700: 0.00371517
# moving average loss in epoch 750: 0.00324978
# moving average loss in epoch 800: 0.00284412
# moving average loss in epoch 850: 0.0025184
# moving average loss in epoch 900: 0.00226947
# moving average loss in epoch 950: 0.0020428
# moving average loss in epoch 1000: 0.00184609
# --- repeat 3 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.20978
# moving average loss in epoch 100: 0.137954
# moving average loss in epoch 150: 0.111012
# moving average loss in epoch 200: 0.108711
# moving average loss in epoch 250: 0.105542
# moving average loss in epoch 300: 0.100794
# moving average loss in epoch 350: 0.0966296
# moving average loss in epoch 400: 0.0942091
# moving average loss in epoch 450: 0.0912118
# moving average loss in epoch 500: 0.0850381
# moving average loss in epoch 550: 0.0801376
# moving average loss in epoch 600: 0.0732712
# moving average loss in epoch 650: 0.0625226
# moving average loss in epoch 700: 0.0572009
# moving average loss in epoch 750: 0.0498511
# moving average loss in epoch 800: 0.0430405
# moving average loss in epoch 850: 0.0369584
# moving average loss in epoch 900: 0.0313984
# moving average loss in epoch 950: 0.0249421
# moving average loss in epoch 1000: 0.0208858
# -- model: GRU-MM --
# moving average loss in epoch 50: 1.73662
# moving average loss in epoch 100: 0.660801
# moving average loss in epoch 150: 0.320516
# moving average loss in epoch 200: 0.151487
# moving average loss in epoch 250: 0.0630518
# moving average loss in epoch 300: 0.0315951
# moving average loss in epoch 350: 0.019624
# moving average loss in epoch 400: 0.013665
# moving average loss in epoch 450: 0.0101498
# moving average loss in epoch 500: 0.00795283
# moving average loss in epoch 550: 0.00631751
# moving average loss in epoch 600: 0.00521708
# moving average loss in epoch 650: 0.00442871
# moving average loss in epoch 700: 0.00381882
# moving average loss in epoch 750: 0.00330373
# moving average loss in epoch 800: 0.00290986
# moving average loss in epoch 850: 0.00258975
# moving average loss in epoch 900: 0.0023409
# moving average loss in epoch 950: 0.00210185
# moving average loss in epoch 1000: 0.00191061
# GRU: 0.389538 +- 0.0118318 (took 448.031 seconds)
# GRU-MM: 0.0269318 +- 0.000646062 (took 475.953 seconds)
# ------ Task 3 of 5: repeat_copy -----
# --- repeat 1 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.217185
# moving average loss in epoch 100: 0.175635
# moving average loss in epoch 150: 0.151042
# moving average loss in epoch 200: 0.13766
# moving average loss in epoch 250: 0.130544
# moving average loss in epoch 300: 0.125817
# moving average loss in epoch 350: 0.122057
# moving average loss in epoch 400: 0.114553
# moving average loss in epoch 450: 0.108149
# moving average loss in epoch 500: 0.101298
# moving average loss in epoch 550: 0.0848811
# moving average loss in epoch 600: 0.0726074
# moving average loss in epoch 650: 0.0555268
# moving average loss in epoch 700: 0.0404174
# moving average loss in epoch 750: 0.0270357
# moving average loss in epoch 800: 0.0195323
# moving average loss in epoch 850: 0.0125038
# moving average loss in epoch 900: 0.00825684
# moving average loss in epoch 950: 0.00548948
# moving average loss in epoch 1000: 0.00430056
# -- model: GRU-MM --
# moving average loss in epoch 50: 1.32848
# moving average loss in epoch 100: 0.49524
# moving average loss in epoch 150: 0.222131
# moving average loss in epoch 200: 0.0807665
# moving average loss in epoch 250: 0.0349569
# moving average loss in epoch 300: 0.0200188
# moving average loss in epoch 350: 0.0133319
# moving average loss in epoch 400: 0.00962854
# moving average loss in epoch 450: 0.00724045
# moving average loss in epoch 500: 0.00576645
# moving average loss in epoch 550: 0.00469345
# moving average loss in epoch 600: 0.00382922
# moving average loss in epoch 650: 0.00327025
# moving average loss in epoch 700: 0.0028002
# moving average loss in epoch 750: 0.00243761
# moving average loss in epoch 800: 0.00213325
# moving average loss in epoch 850: 0.00187076
# moving average loss in epoch 900: 0.00168004
# moving average loss in epoch 950: 0.00152818
# moving average loss in epoch 1000: 0.0013583
# --- repeat 2 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.21976
# moving average loss in epoch 100: 0.178433
# moving average loss in epoch 150: 0.159905
# moving average loss in epoch 200: 0.142714
# moving average loss in epoch 250: 0.134378
# moving average loss in epoch 300: 0.130711
# moving average loss in epoch 350: 0.126663
# moving average loss in epoch 400: 0.121191
# moving average loss in epoch 450: 0.114361
# moving average loss in epoch 500: 0.101666
# moving average loss in epoch 550: 0.0892855
# moving average loss in epoch 600: 0.0735965
# moving average loss in epoch 650: 0.0561797
# moving average loss in epoch 700: 0.0422868
# moving average loss in epoch 750: 0.0285227
# moving average loss in epoch 800: 0.0183615
# moving average loss in epoch 850: 0.0127537
# moving average loss in epoch 900: 0.0078176
# moving average loss in epoch 950: 0.00493705
# moving average loss in epoch 1000: 0.00376756
# -- model: GRU-MM --
# moving average loss in epoch 50: 1.3351
# moving average loss in epoch 100: 0.4916
# moving average loss in epoch 150: 0.206249
# moving average loss in epoch 200: 0.0728649
# moving average loss in epoch 250: 0.0325631
# moving average loss in epoch 300: 0.0191083
# moving average loss in epoch 350: 0.0125979
# moving average loss in epoch 400: 0.00909987
# moving average loss in epoch 450: 0.00693756
# moving average loss in epoch 500: 0.00542546
# moving average loss in epoch 550: 0.00440133
# moving average loss in epoch 600: 0.00367732
# moving average loss in epoch 650: 0.00308567
# moving average loss in epoch 700: 0.00264497
# moving average loss in epoch 750: 0.00231382
# moving average loss in epoch 800: 0.00203945
# moving average loss in epoch 850: 0.00179159
# moving average loss in epoch 900: 0.00159964
# moving average loss in epoch 950: 0.00143643
# moving average loss in epoch 1000: 0.0013037
# --- repeat 3 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 0.21723
# moving average loss in epoch 100: 0.180762
# moving average loss in epoch 150: 0.165422
# moving average loss in epoch 200: 0.155305
# moving average loss in epoch 250: 0.140652
# moving average loss in epoch 300: 0.133712
# moving average loss in epoch 350: 0.131575
# moving average loss in epoch 400: 0.124638
# moving average loss in epoch 450: 0.119208
# moving average loss in epoch 500: 0.111839
# moving average loss in epoch 550: 0.0991133
# moving average loss in epoch 600: 0.0826947
# moving average loss in epoch 650: 0.066292
# moving average loss in epoch 700: 0.0509034
# moving average loss in epoch 750: 0.032625
# moving average loss in epoch 800: 0.0208165
# moving average loss in epoch 850: 0.0128102
# moving average loss in epoch 900: 0.0092977
# moving average loss in epoch 950: 0.00542272
# moving average loss in epoch 1000: 0.00385556
# -- model: GRU-MM --
# moving average loss in epoch 50: 1.29787
# moving average loss in epoch 100: 0.480088
# moving average loss in epoch 150: 0.206464
# moving average loss in epoch 200: 0.0726034
# moving average loss in epoch 250: 0.0319044
# moving average loss in epoch 300: 0.0186642
# moving average loss in epoch 350: 0.012658
# moving average loss in epoch 400: 0.00901071
# moving average loss in epoch 450: 0.00688037
# moving average loss in epoch 500: 0.00546081
# moving average loss in epoch 550: 0.00442267
# moving average loss in epoch 600: 0.00366539
# moving average loss in epoch 650: 0.00312249
# moving average loss in epoch 700: 0.00268351
# moving average loss in epoch 750: 0.00232065
# moving average loss in epoch 800: 0.0020335
# moving average loss in epoch 850: 0.0017985
# moving average loss in epoch 900: 0.00161357
# moving average loss in epoch 950: 0.00144574
# moving average loss in epoch 1000: 0.00130937
# GRU: 0.445747 +- 0.0150524 (took 1063.18 seconds)
# GRU-MM: 0.0201486 +- 0.00102987 (took 869.846 seconds)
# ------ Task 4 of 5: signal_copy -----
# --- repeat 1 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 886.771
# moving average loss in epoch 100: 740.045
# moving average loss in epoch 150: 726.217
# moving average loss in epoch 200: 505
# moving average loss in epoch 250: 727.621
# moving average loss in epoch 300: 767.261
# moving average loss in epoch 350: 651.56
# moving average loss in epoch 400: 393.723
# moving average loss in epoch 450: 488.027
# moving average loss in epoch 500: 650.681
# moving average loss in epoch 550: 901.012
# moving average loss in epoch 600: 739.086
# moving average loss in epoch 650: 897.329
# moving average loss in epoch 700: 766.959
# moving average loss in epoch 750: 603.053
# moving average loss in epoch 800: 551.246
# moving average loss in epoch 850: 630.427
# moving average loss in epoch 900: 645.703
# moving average loss in epoch 950: 807.632
# moving average loss in epoch 1000: 740.903
# -- model: GRU-MM --
# moving average loss in epoch 50: 749.64
# moving average loss in epoch 100: 788.57
# moving average loss in epoch 150: 795.241
# moving average loss in epoch 200: 807.605
# moving average loss in epoch 250: 895.155
# moving average loss in epoch 300: 810.152
# moving average loss in epoch 350: 379.865
# moving average loss in epoch 400: 551.022
# moving average loss in epoch 450: 657.362
# moving average loss in epoch 500: 446.359
# moving average loss in epoch 550: 791.102
# moving average loss in epoch 600: 466.152
# moving average loss in epoch 650: 666.401
# moving average loss in epoch 700: 760.89
# moving average loss in epoch 750: 724.052
# moving average loss in epoch 800: 809.805
# moving average loss in epoch 850: 532.606
# moving average loss in epoch 900: 838.144
# moving average loss in epoch 950: 678.841
# moving average loss in epoch 1000: 721.487
# --- repeat 2 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 145.954
# moving average loss in epoch 100: 150.391
# moving average loss in epoch 150: 150.216
# moving average loss in epoch 200: 127.993
# moving average loss in epoch 250: 179.179
# moving average loss in epoch 300: 128.172
# moving average loss in epoch 350: 126.298
# moving average loss in epoch 400: 145.233
# moving average loss in epoch 450: 142.197
# moving average loss in epoch 500: 106.317
# moving average loss in epoch 550: 136.071
# moving average loss in epoch 600: 110.817
# moving average loss in epoch 650: 144.461
# moving average loss in epoch 700: 152.571
# moving average loss in epoch 750: 136.645
# moving average loss in epoch 800: 151.509
# moving average loss in epoch 850: 155.103
# moving average loss in epoch 900: 148.588
# moving average loss in epoch 950: 140.421
# moving average loss in epoch 1000: 125.485
# -- model: GRU-MM --
# moving average loss in epoch 50: 162.154
# moving average loss in epoch 100: 144.409
# moving average loss in epoch 150: 156.357
# moving average loss in epoch 200: 147.479
# moving average loss in epoch 250: 116.82
# moving average loss in epoch 300: 147.629
# moving average loss in epoch 350: 104.237
# moving average loss in epoch 400: 130.162
# moving average loss in epoch 450: 95.8833
# moving average loss in epoch 500: 126.529
# moving average loss in epoch 550: 95.6402
# moving average loss in epoch 600: 116.888
# moving average loss in epoch 650: 90.6227
# moving average loss in epoch 700: 86.7091
# moving average loss in epoch 750: 108.045
# moving average loss in epoch 800: 108.819
# moving average loss in epoch 850: 104.365
# moving average loss in epoch 900: 108.509
# moving average loss in epoch 950: 93.4065
# moving average loss in epoch 1000: 87.8396
# --- repeat 3 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 10.0363
# moving average loss in epoch 100: 11.4279
# moving average loss in epoch 150: 10.3016
# moving average loss in epoch 200: 12.2846
# moving average loss in epoch 250: 10.443
# moving average loss in epoch 300: 10.5737
# moving average loss in epoch 350: 12.0553
# moving average loss in epoch 400: 12.2822
# moving average loss in epoch 450: 11.0688
# moving average loss in epoch 500: 12.7705
# moving average loss in epoch 550: 10.3641
# moving average loss in epoch 600: 11.074
# moving average loss in epoch 650: 11.838
# moving average loss in epoch 700: 10.6109
# moving average loss in epoch 750: 11.3599
# moving average loss in epoch 800: 11.4871
# moving average loss in epoch 850: 11.7823
# moving average loss in epoch 900: 12.4359
# moving average loss in epoch 950: 10.5991
# moving average loss in epoch 1000: 10.198
# -- model: GRU-MM --
# moving average loss in epoch 50: 10.8829
# moving average loss in epoch 100: 9.94995
# moving average loss in epoch 150: 12.5739
# moving average loss in epoch 200: 10.6108
# moving average loss in epoch 250: 9.78846
# moving average loss in epoch 300: 7.87892
# moving average loss in epoch 350: 10.6452
# moving average loss in epoch 400: 7.84523
# moving average loss in epoch 450: 8.16805
# moving average loss in epoch 500: 8.71408
# moving average loss in epoch 550: 9.31842
# moving average loss in epoch 600: 8.0685
# moving average loss in epoch 650: 8.37223
# moving average loss in epoch 700: 7.92013
# moving average loss in epoch 750: 8.70301
# moving average loss in epoch 800: 7.87127
# moving average loss in epoch 850: 6.46752
# moving average loss in epoch 900: 7.65547
# moving average loss in epoch 950: 5.53623
# moving average loss in epoch 1000: 5.78667
# GRU: 11.491 +- 11.8975 (took 12147.1 seconds)
# GRU-MM: 11.4967 +- 11.9164 (took 27377.2 seconds)
# ------ Task 5 of 5: image_copy -----
# --- repeat 1 of 3 ---
# -- model: GRU --
# moving average loss in epoch 50: 4657.03
